# %%
import pickle

# Load the data from the specified pickle file
with open('/home/saya/chario/upstream_character_tasks/data/progress_backup/2024-01-11__08-39-50.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
data.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %%
data[5]['use_case_data']
# Out:
# [{'id': '1XKJPaGk-ijEWa0vmf7CFpfVzygxlpJXx',
#   'colab_link': 'https://colab.research.google.com/drive/1XKJPaGk-ijEWa0vmf7CFpfVzygxlpJXx',
#   'summary': 'User seeks assistance for coding a string manipulation task.',
#   'tags': ['coding',
#    'string manipulation',
#    'programming help',
#    'python',
#    'software development']},
#  {'id': '12It1-2mgSUtm1amtvxYh-HR9r82k2q94',
#   'colab_link': 'https://colab.research.google.com/drive/12It1-2mgSUtm1amtvxYh-HR9r82k2q94',
#   'summary': 'User seeks assistance for software development testing.',
#   'tags': ['software development',
#    'testing',
#    'programming',
#    'JavaScript',
#    'unit testing']},
#  {'id': '1FsXfRvjAjTy8StlvJwunVBgmXiIVO-0G',
#   'colab_link': 'https://colab.research.google.com/drive/1FsXfRvjAjTy8StlvJwunVBgmXiIVO-0G',
#   'summary': 'The user is troubleshooting software issues after a system upgrade.',
#   'tags': ['troubleshooting',
#    'software issue',
#    'system upgrade',
# ...
